# %% [markdown]
# <a href="https://colab.research.google.com/github/arruenicol/colab/blob/main/alumnos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

pd.read_csv(url)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
datos = pd.read_csv(url, sep=',')

# %%
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
datos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
df = datos.fillna(0)

# %%
df.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %%
df_remove = df.query('Nombre in ["Alicia", "Carlos"]')

# %%
df_remove
# Out:
#    Nombre  Edad  Nota Aprobado
# 7  Carlos    19   6.0    False
# 8  Alicia    35   5.6    False

# %%
df_remove = df.query('Nombre in ["Alicia", "Carlos"]').index

# %%
df_remove
# Out:
# Index([7, 8], dtype='int64')

# %%
df.drop(df_remove, inplace=True, axis=0)

# %%
df
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
df.query('Nombre in ["Alicia", "Carlos"]')
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado]
# Index: []

# %%
alumnos_aprobados = df.query('Aprobado == "True"')

# %%
alumnos_aprobados
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 4      Brian    21  10.0     True
# 6    Daniela    21   7.0     True
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 15    Milena    29   7.0     True

# %%
alumnos_aprobados.to_csv('alumnos_aprobados.csv', index=False, sep=',')

# %%
alumnos_aprobados.replace(7.0, 8.0)
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 4      Brian    21  10.0     True
# 6    Daniela    21   8.0     True
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 15    Milena    29   8.0     True

# %%
alumnos_aprobados = alumnos_aprobados.replace(7.0, 8.0)

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

pd.read_csv(url)

datos = pd.read_csv(url, sep=',')

datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
df = datos.fillna(0)
df.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %%
df
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
df['Puntos_extras'] = df['Nota'].apply(lambda x: x*0.4)

# %%
df
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras
# 0    Alberto    20   7.5       True           3.00
# 1        Ana    18   0.0      False           0.00
# 2     Camila    27   2.5      False           1.00
# 3      David    18   5.0      False           2.00
# 4      Brian    21  10.0       True           4.00
# 5      Bruna    23   0.0      False           0.00
# 6    Daniela    21   7.0       True           2.80
# 7     Carlos    19   6.0      False           2.40
# 8     Alicia    35   5.6      False           2.24
# 9     Victor    28   0.0      False           0.00
# 10    Danilo    21   0.0      False           0.00
# 11   Ignacio    24   4.5      False           1.80
# 12  Stephany    26  10.0       True           4.00
# 13    Miriam    25   9.0       True           3.60
# 14     Pablo    37   0.0      False           0.00
# 15    Milena    29   7.0       True           2.80
# 16     Lucas    33   0.0      False           0.00
# ...

# %%
df['Notas_finales'] = df['Nota'] + df['Puntos_extras']

# %%
df
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales
# 0    Alberto    20   7.5       True           3.00          10.50
# 1        Ana    18   0.0      False           0.00           0.00
# 2     Camila    27   2.5      False           1.00           3.50
# 3      David    18   5.0      False           2.00           7.00
# 4      Brian    21  10.0       True           4.00          14.00
# 5      Bruna    23   0.0      False           0.00           0.00
# 6    Daniela    21   7.0       True           2.80           9.80
# 7     Carlos    19   6.0      False           2.40           8.40
# 8     Alicia    35   5.6      False           2.24           7.84
# 9     Victor    28   0.0      False           0.00           0.00
# 10    Danilo    21   0.0      False           0.00           0.00
# 11   Ignacio    24   4.5      False           1.80           6.30
# 12  Stephany    26  10.0       True           4.00          14.00
# ...

# %%
df['Aprobado_final'] = df['Notas_finales'].apply(lambda x: 'True' if x >= 7 else 'False')

# %%
df
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.5       True           3.00          10.50
# 1        Ana    18   0.0      False           0.00           0.00
# 2     Camila    27   2.5      False           1.00           3.50
# 3      David    18   5.0      False           2.00           7.00
# 4      Brian    21  10.0       True           4.00          14.00
# 5      Bruna    23   0.0      False           0.00           0.00
# 6    Daniela    21   7.0       True           2.80           9.80
# 7     Carlos    19   6.0      False           2.40           8.40
# 8     Alicia    35   5.6      False           2.24           7.84
# 9     Victor    28   0.0      False           0.00           0.00
# 10    Danilo    21   0.0      False           0.00           0.00
# 11   Ignacio    24   4.5      False           1.80           6.30
# 12  Stephany    26  10.0       True           4.00          14.00
# ...

# %%
df.query('Aprobado == "False" & Aprobado_final == "True"')
# Out:
#    Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales Aprobado_final
# 3   David    18   5.0    False           2.00           7.00           True
# 7  Carlos    19   6.0    False           2.40           8.40           True
# 8  Alicia    35   5.6    False           2.24           7.84           True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre          18 non-null     object
#  1   Edad            18 non-null     int64
#  2   Nota            18 non-null     float64
#  3   Aprobado        18 non-null     object
#  4   Puntos_extras   18 non-null     float64
#  5   Notas_finales   18 non-null     float64
#  6   Aprobado_final  18 non-null     bool
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 1014.0+ bytes
